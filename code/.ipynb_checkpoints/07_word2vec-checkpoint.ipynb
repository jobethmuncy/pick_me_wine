# %% [markdown]
# # Word2Vec and Doc2Vec Models

# %%
import pandas as pd
import numpy as np
import regex as re
import nltk
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

import collections
from collections import Counter

from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer, word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from bs4 import BeautifulSoup
from gensim.models.word2vec import Word2Vec
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from scipy import sparse
from sklearn.metrics.pairwise import pairwise_distances
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from scipy import sparse
from sklearn.metrics.pairwise import pairwise_distances, cosine_similarity

# %%
df = pd.read_csv('../data/test_lower_wines.csv')
df.head()
# Out:
#                                                 name      producer vintage  \
# 0  Skin Contact Silvaner "Kleine Heimat," 2Naturk...  2Naturkinder    2017
# 1                       Fledermaus Rot, 2Naturkinder  2Naturkinder    2018
# 2                              Sekt Weiss, 50o N  NV          50oN      NV
# 3                        Fuga, Mencía, Ribeira Sacra        A Fuga    2017
# 4              Cirò Rosso Classico Superiore, A Vita        A Vita    2016
#
#   bottle_size  color  price  country         region  \
# 0         750  white     24  germany        franken
# 1         750    red      0  germany        franken
# 2         750  white     14  germany       rheingau
# 3         750    red      0    spain  ribeira sacra
# 4         750    red     21    italy       calabria
#
#                                                  url  \
# 0  https://www.astorwines.com/SearchResultsSingle...
# 1  https://www.astorwines.com/SearchResultsSingle...
# 2  https://www.astorwines.com/SearchResultsSingle...
# 3  https://www.astorwines.com/SearchResultsSingle...
# 4  https://www.astorwines.com/SearchResultsSingle...
#
#                                          description  \
# 0  Made from 100% Silvaner, this white wine ferme...
# 1  Made from Schwartz Riesling (aka Pinot Meunier...
# 2  Sometimes you just want to drink a wine becaus...
# 3  FUGA MENCIAJust barely opaque, and dark garnet...
# 4  Here is a wine with a distinct, alluring chara...
#
#                                  grape subregion  \
# 0                             silvaner         0
# 1                        pinot meunier         0
# 2  müller-thurgau pinot blanc sylvaner         0
# 3                               mencía         0
# 4                            gaglioppo      cirò
#
#                                    description_clean  \
# 0  made silvaner white wine ferments skins days g...
# 1  made schwartz riesling pinot meunier grapes ha...
# 2  sometimes want drink wine tastes good one wine...
# 3  fuga menciajust barely opaque dark garnet colo...
# 4  wine distinct alluring character dates back an...
#
#                                                 text
# 0  franken white germany made silvaner white wine...
# 1  franken red germany made schwartz riesling pin...
# 2  rheingau white germany sometimes want drink wi...
# 3  ribeira sacra red spain fuga menciajust barely...
# 4  calabriacirò red italy wine distinct alluring ...

# %%
df.duplicated().sum()
# Out:
# 678

# %%
df.drop_duplicates(subset=None, keep='first', inplace=True)

# %%
df.shape
# Out:
# (12156, 14)

# %%
df[df['color'].isnull()] = 'red'

# %%
# drop ciders
cider_rows = df[df['grape'] == 'apple'].index
df.drop(cider_rows, inplace=True)

# %%
df.shape
# Out:
# (12145, 14)

# %% [markdown]
# # Word2Vec with CBOW
# Predict word in the middle, better accuracy for frequent words

# %% [markdown]
# For Vec models, need to the all tokenized words-split the text here

# %%
df['description_clean_2'] = [str(row).split() for row in df['description_clean']]
df['text_2'] = [str(row).split() for row in df['text']]

# %%
w2v_cbow = Word2Vec(df['description_clean_2'], 
                    min_count = 5, # frequency dropped before training occurs
                    workers = 4) # independent threads working

# %%
w2v_cbow.wv.most_similar_cosmul('sparkling')
# Out:
# [('ros', 0.9102315306663513),
#  ('sparkler', 0.8830097317695618),
#  ('festive', 0.8785400390625),
#  ('type', 0.8728392124176025),
#  ('makes', 0.8718475103378296),
#  ('everyday', 0.8690309524536133),
#  ('affordable', 0.8683280944824219),
#  ('moscato', 0.8632428050041199),
#  ('cava', 0.8581907749176025),
#  ('brut', 0.8523533940315247)]

# %%
text_w2v_cbow = Word2Vec(df['text_2'], 
                    min_count = 5, # frequency dropped before training occurs
                    workers = 4) # independent threads working

# %%
text_w2v_cbow.wv.most_similar_cosmul('sparkling')
# Out:
# [('ros', 0.8871276378631592),
#  ('italychampagne', 0.8793519735336304),
#  ('piedmont,', 0.8574734926223755),
#  ('languedoc-roussillon', 0.846211314201355),
#  ('white', 0.8390681743621826),
#  ('penedès', 0.8385623097419739),
#  ('loirenantes', 0.8345789313316345),
#  ('dão', 0.8276304602622986),
#  ('and', 0.8275236487388611),
#  ('nahe,', 0.8246423602104187)]

# %% [markdown]
# # Word2Vec with SkipGram
# Predicts context, rare words or phrases<br>
# The SkipGram brings back more similar words than CBOW

# %%
w2v_sg = Word2Vec(df['description_clean_2'],
                  min_count=1, 
                  sg=1, 
                  workers=3)

# %%
w2v_sg.wv.most_similar_cosmul(positive=['red', 'lush', 'juicy', 'italy'])
# Out:
# [('abounds', 0.5515811443328857),
#  ('overflows', 0.5425879955291748),
#  ('endearing', 0.5424729585647583),
#  ('sassy', 0.5420688986778259),
#  ('scrumptious', 0.5410647392272949),
#  ('cheery', 0.5407906174659729),
#  ('jazzy', 0.5400341749191284),
#  ('charmingly', 0.5380794405937195),
#  ('plethora', 0.5352271199226379),
#  ('uncomplicated', 0.5332666635513306)]

# %%
text_w2v_sg = Word2Vec(df['text_2'],
                  min_count=1, 
                  sg=1, 
                  workers=3)

# %%
text_w2v_sg.wv.most_similar_cosmul('red')
# Out:
# [('nandark', 0.8667792081832886),
#  ('nanrich', 0.8603235483169556),
#  ('nanblack', 0.854231595993042),
#  ('nana', 0.8525999784469604),
#  ('nanred', 0.8523722290992737),
#  ('nandeep', 0.8514415621757507),
#  ('margaux,', 0.8423077464103699),
#  ('nancherry', 0.8416593670845032),
#  ('st-julien,', 0.8414425253868103),
#  ('nanripe', 0.8412728309631348)]

# %% [markdown]
# # Doc2Vec
# Specific document vector added to Word2Vec

# %%
summ_tokens = df_white['description_clean_2']

# %%
# Try bi grams

# %%
from gensim.models import Phrases
bigram = Phrases(summ_tokens, min_count=1, threshold=3, delimiter=b' ')
bigram_docs = []
for doc in summ_tokens:
    bigram_docs.append(bigram[doc])
tagged_bigrams = [TaggedDocument(bigrams, [i]) for i, bigrams in enumerate(bigram_docs)]
bigrams_model = Doc2Vec(vector_size = 200,
                        min_count = 3,
                        window = 10,
                        epochs = 20)
bigrams_model.build_vocab(tagged_bigrams)
bigrams_model.train(tagged_bigrams,
                    total_examples = d2v.corpus_count,
                    epochs = d2v.epochs)

# %%
df_white = df[df['color'] == 'white']

# %%
df_white.head()
# Out:
#                                                  name           producer  \
# 0   Skin Contact Silvaner "Kleine Heimat," 2Naturk...       2Naturkinder
# 2                               Sekt Weiss, 50o N  NV               50oN
# 5          Dhron Hofberg Riesling Kabinett, A.J. Adam          A.J. Adam
# 10  The Abarbanel, "Les Chemins de Favarelle" Char...    Abarbenel Wines
# 12                          Kerner, Abbazia Novacella  Abbazia Novacella
#
#    vintage bottle_size  color price  country                region  \
# 0     2017         750  white    24  germany               franken
# 2       NV         750  white    14  germany              rheingau
# 5     2018         750  white    23  germany      mosel-saar-ruwer
# 10    2016         750  white     0   france  languedoc-roussillon
# 12    2018         750  white    21    italy   trentino-alto adige
#
#                                                   url  \
# 0   https://www.astorwines.com/SearchResultsSingle...
# 2   https://www.astorwines.com/SearchResultsSingle...
# 5   https://www.astorwines.com/SearchResultsSingle...
# 10  https://www.astorwines.com/SearchResultsSingle...
# 12  https://www.astorwines.com/SearchResultsSingle...
#
#                                           description  \
# 0   Made from 100% Silvaner, this white wine ferme...
# 2   Sometimes you just want to drink a wine becaus...
# 5   For me wine is almost always part of a larger ...
# 10  Unoaked Chardonnay. Kosher for Passover and Me...
# 12  There's so much history in this bottle it woul...
#
#                                   grape     subregion  \
# 0                              silvaner             0
# 2   müller-thurgau pinot blanc sylvaner             0
# 5                              riesling  mittel-mosel
# 10                           chardonnay             0
# 12                               kerner    alto adige
#
#                                     description_clean  \
# 0   made silvaner white wine ferments skins days g...
# 2   sometimes want drink wine tastes good one wine...
# 5   wine almost always part larger story pour food...
# 10        unoaked chardonnay kosher passover mevushal
# 12  much history bottle would drain ink pens write...
#
#                                                  text  \
# 0   franken white germany made silvaner white wine...
# 2   rheingau white germany sometimes want drink wi...
# 5   mosel-saar-ruwermittel-mosel white germany win...
# 10  languedoc-roussillon white france unoaked char...
# 12  trentino-alto adigealto adige white italy much...
#
#                                   description_clean_2  \
# 0   [made, silvaner, white, wine, ferments, skins,...
# 2   [sometimes, want, drink, wine, tastes, good, o...
# 5   [wine, almost, always, part, larger, story, po...
# 10  [unoaked, chardonnay, kosher, passover, mevushal]
# 12  [much, history, bottle, would, drain, ink, pen...
#
#                                                text_2
# 0   [franken, white, germany, made, silvaner, whit...
# 2   [rheingau, white, germany, sometimes, want, dr...
# 5   [mosel-saar-ruwermittel-mosel, white, germany,...
# 10  [languedoc-roussillon, white, france, unoaked,...
# 12  [trentino-alto, adigealto, adige, white, italy...

# %%
df_red = df[df['color'] == 'red']

# %%
# Clay from NLT project

# %%
def create_tagged_document(list_of_list_of_words):
    for i, list_of_words in enumerate(list_of_list_of_words):
        yield TaggedDocument(list_of_words, [i])

# %%
data_tag = list(create_tagged_document(df_white['description_clean_2']))

# %%
d2v = Doc2Vec(vector_size=100, min_count=3, epochs=30)

# %%
d2v.build_vocab(data_tag)

# %%
d2v.train(data_tag, total_examples=d2v.corpus_count, epochs=d2v.epochs)

# %%
df_white.head(30)
# Out:
#                                                  name  \
# 0   Skin Contact Silvaner "Kleine Heimat," 2Naturk...
# 2                               Sekt Weiss, 50o N  NV
# 5          Dhron Hofberg Riesling Kabinett, A.J. Adam
# 10  The Abarbanel, "Les Chemins de Favarelle" Char...
# 12                          Kerner, Abbazia Novacella
# 13                 Pinot Grigio, Abbazia di Novacella
# 21       Agrapart "Venus" Blanc de Blancs Brut Nature
# 22       Agrapart "Venus" Blanc de Blancs Brut Nature
# 23         Agrapart "Crus 7" Blanc de Blancs Brut  NV
# 29                           Pinot Blanc, Albert Mann
# 30                  Riesling Schlossberg, Albert Mann
# 37                  Bourgogne Blanc "Chitry," De Moor
# 39                  Alkoomi Riesling, Frankland River
# 41           Sancerre "La Moussière," Alphonse Mellot
# 42  HalfBottle of Alta Alella "Mirgin," Cava Brut ...
# 46                Ansonaco, Altura, Famiglia Carfagna
# 47    Grüner Veltliner Dürnstein Federspiel, Alzinger
# 49                  Bourgogne Aligoté, Dom. Guy Amiot
# 50     Bourgogne Blanc "Cuvée Flavie", Dom. Guy Amiot
# 52                           Bouzeron, Dom. Guy Amiot
# 53  ChassagneMontrachet Blanc 1er Cru "Macherelle"...
# 54  ChassagneMontrachet Blanc Vieilles Vignes, Dom...
# 57             Pétillant Naturel "Indigeno", Ancarini
# 59  Muscadet de Sèvre et Maine "Gorges," Dom. Mich...
# 60  Muscadet Sèvre et Maine Sur Lie, Dom. Michel B...
# 66                  Pico Angiolino Maule, La Biancara
# 72                              Pinot Gris, Ant Moore
# 73                         Sauvignon Blanc, Ant Moore
# 74          Anthill Farms ‘Peugh Vineyard' Chardonnay
# 80  St.Aubin Blanc 1er Cru "Sur le Sentier du Clou...
#
#                     producer vintage bottle_size  color price      country  \
# 0               2Naturkinder    2017         750  white    24      germany
# 2                       50oN      NV         750  white    14      germany
# 5                  A.J. Adam    2018         750  white    23      germany
# 10           Abarbenel Wines    2016         750  white     0       france
# 12         Abbazia Novacella    2018         750  white    21        italy
# 13         Abbazia Novacella    2018         750  white    24        italy
# 21                  Agrapart    2013         750  white   224       france
# 22                  Agrapart    2012         750  white   214       france
# 23                  Agrapart      NV         750  white     0       france
# 29               Albert Mann    2018         750  white    19       france
# 30               Albert Mann    2017         750  white     0       france
# 37  Alice et Olivier de Moor    2018         750  white     0       france
# 39                   Alkoomi    2019         750  white     0    australia
# 41           Alphonse Mellot    2018         750  white    34       france
# 42               Alta Alella    2017         375  white    10        spain
# 46                    Altura    2017         750  white    41        italy
# 47                  Alzinger    2018         750  white    28      austria
# 49                     Amiot    2017         750  white    25       france
# 50                     Amiot    2017         750  white    31       france
# 52                     Amiot    2017         750  white    29       france
# 53                     Amiot    2016         750  white    86       france
# 54                     Amiot    2016         750  white    64       france
# 57                  Ancarani    2018         750  white     0        italy
# 59      André-Michel Brégeon    2013         750  white    42       france
# 60      André-Michel Brégeon    2018         750  white    18       france
# 66           Angiolino Maule    2017         750  white    31        italy
# 72                 Ant Moore    2017         750  white    14  new zealand
# 73                 Ant Moore    2019         750  white    13  new zealand
# 74             Anthill Farms    2017         750  white    49          usa
# 80            Antoine Jobard    2016         750  white   116       france
#
#                   region                                                url  \
# 0                franken  https://www.astorwines.com/SearchResultsSingle...
# 2               rheingau  https://www.astorwines.com/SearchResultsSingle...
# 5       mosel-saar-ruwer  https://www.astorwines.com/SearchResultsSingle...
# 10  languedoc-roussillon  https://www.astorwines.com/SearchResultsSingle...
# 12   trentino-alto adige  https://www.astorwines.com/SearchResultsSingle...
# 13   trentino-alto adige  https://www.astorwines.com/SearchResultsSingle...
# 21             champagne  https://www.astorwines.com/SearchResultsSingle...
# 22             champagne  https://www.astorwines.com/SearchResultsSingle...
# 23             champagne  https://www.astorwines.com/SearchResultsSingle...
# 29                alsace  https://www.astorwines.com/SearchResultsSingle...
# 30                alsace  https://www.astorwines.com/SearchResultsSingle...
# 37              burgundy  https://www.astorwines.com/SearchResultsSingle...
# 39     western australia  https://www.astorwines.com/SearchResultsSingle...
# 41                 loire  https://www.astorwines.com/SearchResultsSingle...
# 42               penedès  https://www.astorwines.com/SearchResultsSingle...
# 46      isola del giglio  https://www.astorwines.com/SearchResultsSingle...
# 47                wachau  https://www.astorwines.com/SearchResultsSingle...
# 49              burgundy  https://www.astorwines.com/SearchResultsSingle...
# 50              burgundy  https://www.astorwines.com/SearchResultsSingle...
# 52              burgundy  https://www.astorwines.com/SearchResultsSingle...
# 53              burgundy  https://www.astorwines.com/SearchResultsSingle...
# 54              burgundy  https://www.astorwines.com/SearchResultsSingle...
# 57        emilia-romagna  https://www.astorwines.com/SearchResultsSingle...
# 59                 loire  https://www.astorwines.com/SearchResultsSingle...
# 60                 loire  https://www.astorwines.com/SearchResultsSingle...
# 66                veneto  https://www.astorwines.com/SearchResultsSingle...
# 72          south island  https://www.astorwines.com/SearchResultsSingle...
# 73          south island  https://www.astorwines.com/SearchResultsSingle...
# 74            california  https://www.astorwines.com/SearchResultsSingle...
# 80              burgundy  https://www.astorwines.com/SearchResultsSingle...
#
#                                           description  \
# 0   Made from 100% Silvaner, this white wine ferme...
# 2   Sometimes you just want to drink a wine becaus...
# 5   For me wine is almost always part of a larger ...
# 10  Unoaked Chardonnay. Kosher for Passover and Me...
# 12  There's so much history in this bottle it woul...
# 13  The palates of many people have been jaded by ...
# 21  All elegance and minerality, this Champagne is...
# 22  All elegance and minerality, this Champagne is...
# 23  Today, brothers Fabrice and Pascal Agrapart co...
# 29  Alsace will always hold a special place in my ...
# 30  A gorgeous Riesling made from hand-harvested f...
# 37  We have plenty of wines that make us teary-eye...
# 39  Too often, as I walk down the numerous bins fu...
# 41  The Mellots are proud of their history. The fa...
# 42  Good texture and fluffy bubbles with stone fru...
# 46  This golden-colored skin contact 100% Ansonaco...
# 47  Harvested in early October from multiple viney...
# 49  This Aligoté comes from a particularly old plo...
# 50  Domaine Guy Amiot's extraordinary variety of w...
# 52  Wines that express duality are incredible, and...
# 53  From a half-hectare, contiguous plot of 35 yea...
# 54  Domaine Guy Amiot is a 4th generation family-r...
# 57  A sparkling Trebbiano Romagna whose fermentati...
# 59  When I first tasted this wine I thought it had...
# 60  Underneath André-Michel Brégeon’s vineyards li...
# 66  Made from Garganega grape and borne on the vol...
# 72  Ant Moore is the passion project of Anthony "A...
# 73  New Zealand Sauvignon Blanc is well know for b...
# 74  The Chardonnay from Peugh Vineyard is rich, pl...
# 80  Antoine Jobard is best known for his voluptuou...
#
#                                   grape         subregion  \
# 0                              silvaner                 0
# 2   müller-thurgau pinot blanc sylvaner                 0
# 5                              riesling      mittel-mosel
# 10                           chardonnay                 0
# 12                               kerner        alto adige
# 13                         pinot grigio        alto adige
# 21                           chardonnay    côte de blancs
# 22                           chardonnay    côte de blancs
# 23                           chardonnay    côte de blancs
# 29                          pinot blanc                 0
# 30                             riesling                 0
# 37                           chardonnay                 0
# 39                             riesling                 0
# 41                      sauvignon blanc          sancerre
# 42           parellada macabeo xarel-lo                 0
# 46                             ansonaco                 0
# 47                     grüner veltliner                 0
# 49                              aligoté                 0
# 50                           chardonnay                 0
# 52                              aligoté  côte chalonnaise
# 53                           chardonnay    côte de beaune
# 54                           chardonnay    côte de beaune
# 57                            trebbiano           romagna
# 59                   melon de bourgogne            nantes
# 60                   melon de bourgogne            nantes
# 66                            garganega                 0
# 72                           pinot gris       marlborough
# 73                      sauvignon blanc       marlborough
# 74                           chardonnay            sonoma
# 80                           chardonnay    côte de beaune
#
#                                     description_clean  \
# 0   made silvaner white wine ferments skins days g...
# 2   sometimes want drink wine tastes good one wine...
# 5   wine almost always part larger story pour food...
# 10        unoaked chardonnay kosher passover mevushal
# 12  much history bottle would drain ink pens write...
# 13  palates many people jaded pinot grigio often v...
# 21  elegance minerality champagne stunning oysters...
# 22  elegance minerality champagne stunning oysters...
# 23  today brothers fabrice pascal agrapart continu...
# 29  alsace always hold special place heart region ...
# 30  gorgeous riesling made hand harvested fruit vi...
# 37  plenty wines make us teary eyed others maybe s...
# 39  often walk numerous bins full wines come new w...
# 41  mellots proud history family name mentioned ar...
# 42  good texture fluffy bubbles stone fruits orang...
# 46  golden colored skin contact ansonaco demands s...
# 47  harvested early october multiple vineyards rns...
# 49  aligot comes particularly old plot vines plant...
# 50  domaine guy amiot extraordinary variety wines ...
# 52  wines express duality incredible one reasonabl...
# 53  half hectare contiguous plot year old vines pr...
# 54  domaine guy amiot th generation family run win...
# 57  sparkling trebbiano romagna whose fermentation...
# 59  first tasted wine thought chenin blanc warm wo...
# 60  underneath andr michel br geon vineyards lies ...
# 66  made garganega grape borne volcanic soils hill...
# 72  ant moore passion project anthony ant moore ma...
# 73  new zealand sauvignon blanc well know alive fr...
# 74  chardonnay peugh vineyard rich pliant nicely t...
# 80  antoine jobard best known voluptuous meursault...
#
#                                                  text  \
# 0   franken white germany made silvaner white wine...
# 2   rheingau white germany sometimes want drink wi...
# 5   mosel-saar-ruwermittel-mosel white germany win...
# 10  languedoc-roussillon white france unoaked char...
# 12  trentino-alto adigealto adige white italy much...
# 13  trentino-alto adigealto adige white italy pala...
# 21  champagnecôte de blancs white france elegance ...
# 22  champagnecôte de blancs white france elegance ...
# 23  champagnecôte de blancs white france today bro...
# 29  alsace white france alsace always hold special...
# 30  alsace white france gorgeous riesling made han...
# 37  burgundy white france plenty wines make us tea...
# 39  western australia white australia often walk n...
# 41  loiresancerre white france mellots proud histo...
# 42  penedès white spain good texture fluffy bubble...
# 46  isola del giglio white italy golden colored sk...
# 47  wachau white austria harvested early october m...
# 49  burgundy white france aligot comes particularl...
# 50  burgundy white france domaine guy amiot extrao...
# 52  burgundycôte chalonnaise white france wines ex...
# 53  burgundycôte de beaune white france half hecta...
# 54  burgundycôte de beaune white france domaine gu...
# 57  emilia-romagnaromagna white italy sparkling tr...
# 59  loirenantes white france first tasted wine tho...
# 60  loirenantes white france underneath andr miche...
# 66  veneto white italy made garganega grape borne ...
# 72  south islandmarlborough white new zealand ant ...
# 73  south islandmarlborough white new zealand new ...
# 74  californiasonoma white usa chardonnay peugh vi...
# 80  burgundycôte de beaune white france antoine jo...
#
#                                   description_clean_2  \
# 0   [made, silvaner, white, wine, ferments, skins,...
# 2   [sometimes, want, drink, wine, tastes, good, o...
# 5   [wine, almost, always, part, larger, story, po...
# 10  [unoaked, chardonnay, kosher, passover, mevushal]
# 12  [much, history, bottle, would, drain, ink, pen...
# 13  [palates, many, people, jaded, pinot, grigio, ...
# 21  [elegance, minerality, champagne, stunning, oy...
# 22  [elegance, minerality, champagne, stunning, oy...
# 23  [today, brothers, fabrice, pascal, agrapart, c...
# 29  [alsace, always, hold, special, place, heart, ...
# 30  [gorgeous, riesling, made, hand, harvested, fr...
# 37  [plenty, wines, make, us, teary, eyed, others,...
# 39  [often, walk, numerous, bins, full, wines, com...
# 41  [mellots, proud, history, family, name, mentio...
# 42  [good, texture, fluffy, bubbles, stone, fruits...
# 46  [golden, colored, skin, contact, ansonaco, dem...
# 47  [harvested, early, october, multiple, vineyard...
# 49  [aligot, comes, particularly, old, plot, vines...
# 50  [domaine, guy, amiot, extraordinary, variety, ...
# 52  [wines, express, duality, incredible, one, rea...
# 53  [half, hectare, contiguous, plot, year, old, v...
# 54  [domaine, guy, amiot, th, generation, family, ...
# 57  [sparkling, trebbiano, romagna, whose, ferment...
# 59  [first, tasted, wine, thought, chenin, blanc, ...
# 60  [underneath, andr, michel, br, geon, vineyards...
# 66  [made, garganega, grape, borne, volcanic, soil...
# 72  [ant, moore, passion, project, anthony, ant, m...
# 73  [new, zealand, sauvignon, blanc, well, know, a...
# 74  [chardonnay, peugh, vineyard, rich, pliant, ni...
# 80  [antoine, jobard, best, known, voluptuous, meu...
#
#                                                text_2
# 0   [franken, white, germany, made, silvaner, whit...
# 2   [rheingau, white, germany, sometimes, want, dr...
# 5   [mosel-saar-ruwermittel-mosel, white, germany,...
# 10  [languedoc-roussillon, white, france, unoaked,...
# 12  [trentino-alto, adigealto, adige, white, italy...
# 13  [trentino-alto, adigealto, adige, white, italy...
# 21  [champagnecôte, de, blancs, white, france, ele...
# 22  [champagnecôte, de, blancs, white, france, ele...
# 23  [champagnecôte, de, blancs, white, france, tod...
# 29  [alsace, white, france, alsace, always, hold, ...
# 30  [alsace, white, france, gorgeous, riesling, ma...
# 37  [burgundy, white, france, plenty, wines, make,...
# 39  [western, australia, white, australia, often, ...
# 41  [loiresancerre, white, france, mellots, proud,...
# 42  [penedès, white, spain, good, texture, fluffy,...
# 46  [isola, del, giglio, white, italy, golden, col...
# 47  [wachau, white, austria, harvested, early, oct...
# 49  [burgundy, white, france, aligot, comes, parti...
# 50  [burgundy, white, france, domaine, guy, amiot,...
# 52  [burgundycôte, chalonnaise, white, france, win...
# 53  [burgundycôte, de, beaune, white, france, half...
# 54  [burgundycôte, de, beaune, white, france, doma...
# 57  [emilia-romagnaromagna, white, italy, sparklin...
# 59  [loirenantes, white, france, first, tasted, wi...
# 60  [loirenantes, white, france, underneath, andr,...
# 66  [veneto, white, italy, made, garganega, grape,...
# 72  [south, islandmarlborough, white, new, zealand...
# 73  [south, islandmarlborough, white, new, zealand...
# 74  [californiasonoma, white, usa, chardonnay, peu...
# 80  [burgundycôte, de, beaune, white, france, anto...

# %%
d2v.docvecs.most_similar(23)
# Out:
# [(1302, 0.774288535118103),
#  (457, 0.7183742523193359),
#  (771, 0.7134526371955872),
#  (1413, 0.7104878425598145),
#  (586, 0.7024083137512207),
#  (510, 0.6950732469558716),
#  (1373, 0.6934767961502075),
#  (798, 0.6922529935836792),
#  (1326, 0.6852031946182251),
#  (1327, 0.6799265146255493)]

# %%
df.loc[437, 'url']
# Out:
# 'https://www.astorwines.com/SearchResultsSingle.aspx?p=1&search=17840&searchtype=Contains'

# %% [markdown]
# # TFIDF

# %%
tf = TfidfVectorizer(analyzer='word', 
                     ngram_range=(1, 2), 
                     stop_words='english')

tf_matrix = tf.fit_transform(df['description_clean'])
tf_matrix.shape
# Out:
# (12145, 381534)

# %%
cosine_sim = cosine_similarity(tf_matrix, tf_matrix)

recommender = pairwise_distances(cosine_sim, metric='cosine')

recommender.shape
# Out:
# (12145, 12145)

# %%
recommender
# Out:
# array([[0.        , 0.60636978, 0.72231285, ..., 0.77854966, 0.71070869,
#         0.77493859],
#        [0.60636978, 0.        , 0.76262784, ..., 0.82937114, 0.76180263,
#         0.81035657],
#        [0.72231285, 0.76262784, 0.        , ..., 0.56455272, 0.57763284,
#         0.62394855],
#        ...,
#        [0.77854966, 0.82937114, 0.56455272, ..., 0.        , 0.62691373,
#         0.66426633],
#        [0.71070869, 0.76180263, 0.57763284, ..., 0.62691373, 0.        ,
#         0.60203727],
#        [0.77493859, 0.81035657, 0.62394855, ..., 0.66426633, 0.60203727,
#         0.        ]])

# %%
df.head(1)
# Out:
#                                                 name      producer vintage  \
# 0  Skin Contact Silvaner "Kleine Heimat," 2Naturk...  2Naturkinder    2017
#
#   bottle_size  color price  country   region  \
# 0         750  white    24  germany  franken
#
#                                                  url  \
# 0  https://www.astorwines.com/SearchResultsSingle...
#
#                                          description     grape subregion  \
# 0  Made from 100% Silvaner, this white wine ferme...  silvaner         0
#
#                                    description_clean  \
# 0  made silvaner white wine ferments skins days g...
#
#                                                 text  \
# 0  franken white germany made silvaner white wine...
#
#                                  description_clean_2  \
# 0  [made, silvaner, white, wine, ferments, skins,...
#
#                                               text_2
# 0  [franken, white, germany, made, silvaner, whit...

# %%
recommender_df = pd.DataFrame(recommender, 
             index=df.index,
             columns=df['name'])

# %%
recommender_df.head()
# Out:
# name  Skin Contact Silvaner "Kleine Heimat," 2Naturkinder  \
# 0                                              0.000000
# 1                                              0.606370
# 2                                              0.722313
# 3                                              0.677793
# 4                                              0.726989
#
# name  Fledermaus Rot, 2Naturkinder  Sekt Weiss, 50o N  NV  \
# 0                         0.606370               0.722313
# 1                         0.000000               0.762628
# 2                         0.762628               0.000000
# 3                         0.748901               0.487461
# 4                         0.776654               0.609532
#
# name  Fuga, Mencía, Ribeira Sacra  Cirò Rosso Classico Superiore, A Vita  \
# 0                        0.677793                               0.726989
# 1                        0.748901                               0.776654
# 2                        0.487461                               0.609532
# 3                        0.000000                               0.477965
# 4                        0.477965                               0.000000
#
# name  Dhron Hofberg Riesling Kabinett, A.J. Adam  \
# 0                                       0.745429
# 1                                       0.745178
# 2                                       0.642945
# 3                                       0.619790
# 4                                       0.680740
#
# name  Areni "L. 2017021", Aaron Sedrick Rawlins  \
# 0                                      0.688633
# 1                                      0.712811
# 2                                      0.610022
# 3                                      0.471534
# 4                                      0.535245
#
# name  Bierzo Mencía, Abad Dom Bueno  \
# 0                          0.684973
# 1                          0.745318
# 2                          0.570958
# 3                          0.429038
# 4                          0.528320
#
# name  The Abarbanel, "Les Dolmens Rouges" Cabernet Sauvignon  \
# 0                                              0.816716
# 1                                              0.849736
# 2                                              0.686989
# 3                                              0.526843
# 4                                              0.607206
#
# name  The Abarbanel, "Les Chemins de Favarelle" Chardonnay  ...  \
# 0                                              0.955439     ...
# 1                                              0.964093     ...
# 2                                              0.919988     ...
# 3                                              0.928035     ...
# 4                                              0.948577     ...
#
# name  Weingut Gunther Steinmetz Pinot Noir  Messmer Spatburgunder (1 liter)  \
# 0                                 0.873551                         0.981488
# 1                                 0.895577                         0.980191
# 2                                 0.769149                         0.989099
# 3                                 0.659638                         0.986922
# 4                                 0.728645                         0.985973
#
# name  Muller-Catoir Haardt Spatburgunder Trocken  \
# 0                                       0.883200
# 1                                       0.904712
# 2                                       0.779797
# 3                                       0.726716
# 4                                       0.799975
#
# name  Weingut Ziereisen Spatburgunder Schulen Ziereisen  \
# 0                                              0.708942
# 1                                              0.726350
# 2                                              0.511896
# 3                                              0.409554
# 4                                              0.552385
#
# name  Wittmann Spatburgunder  Weingut Darting Pinot Meunier  \
# 0                   0.799446                       0.835188
# 1                   0.759531                       0.772622
# 2                   0.628810                       0.678740
# 3                   0.554667                       0.605509
# 4                   0.655437                       0.673611
#
# name  Hexamer Spatburgunder Weissherbst Halbtrocken  Funf Sangria  \
# 0                                          0.803975      0.778550
# 1                                          0.799007      0.829371
# 2                                          0.652541      0.564553
# 3                                          0.659389      0.539037
# 4                                          0.712169      0.663807
#
# name  Schmitt Sohne Ice Wine (500ML)  \
# 0                           0.710709
# 1                           0.761803
# 2                           0.577633
# 3                           0.495625
# 4                           0.596200
#
# name  Dr. Loosen Eiswein Riesling (375ML Half-bottle)
# 0                                            0.774939
# 1                                            0.810357
# 2                                            0.623949
# 3                                            0.584161
# 4                                            0.682985
#
# [5 rows x 12145 columns]

# %%
tf2 = TfidfVectorizer(analyzer='word', 
                     ngram_range=(1, 2), 
                     stop_words='english')
tf_matrix2 = tf2.fit_transform(df['text'])
cosine_sim = cosine_similarity(tf_matrix2, tf_matrix2)
recommender2 = pairwise_distances(cosine_sim, metric='cosine')
recommender_df2 = pd.DataFrame(recommender2, 
             index=df.index,
             columns=df['name'])

# %%
df.loc[5550:5555]
# Out:
#                                                    name producer vintage  \
# 5550    Gary Farrell Russian River Selection Pinot Noir        0    2017
# 5551             Lynmar Winery Russian River Pinot Noir        0    2018
# 5552                   Oakville Winery Estate Zinfandel        0    2017
# 5553  Trefethen Cabernet Sauvignon Estate (375ML hal...        0    2016
# 5554                               Highway 12 Red Blend        0    2016
# 5555          Frog's Leap Zinfandel (375ML half-bottle)        0    2018
#
#      bottle_size color price country  \
# 5550         750   red    47     usa
# 5551         750   red    49     usa
# 5552         750   red    27     usa
# 5553         375   red    31     usa
# 5554         750   red    24     usa
# 5555         375   red    16     usa
#
#                                         region  \
# 5550  russian river, sonoma county, california
# 5551  russian river, sonoma county, california
# 5552         oakville, napa valley, california
# 5553                   napa valley, california
# 5554                 sonoma county, california
# 5555                   napa valley, california
#
#                                                     url  \
# 5550  https://www.wine.com/product/gary-farrell-russ...
# 5551  https://www.wine.com/product/lynmar-winery-rus...
# 5552  https://www.wine.com/product/oakville-winery-e...
# 5553  https://www.wine.com/product/trefethen-caberne...
# 5554  https://www.wine.com/product/highway-12-red-bl...
# 5555  https://www.wine.com/product/frogs-leap-zinfan...
#
#                                             description               grape  \
# 5550  [This is an outstanding showcase of appellatio...          pinot noir
# 5551  nanThe 2018 Lynmar Winery Russian River Pinot ...          pinot noir
# 5552  [C: The 2017 Oakville Winery Zinfandel does an...           zinfandel
# 5553  [<p><span style="color: rgb(66, 64, 64);">With...  cabernet sauvignon
# 5554  nanA fruity, leathery nose offers a glimpse in...    other red blends
# 5555  [<p>Close your eyes, smell this wine, and you ...           zinfandel
#
#      subregion                                  description_clean  \
# 5550         0  outstanding showcase appellation sourced stell...
# 5551         0  nanthe lynmar winery russian river pinot noir ...
# 5552         0  oakville winery zinfandel excellent job presen...
# 5553         0  span style color rgb fresh herb notes lively a...
# 5554         0  nana fruity leathery nose offers glimpse unfol...
# 5555         0  close eyes smell wine might think moved ruther...
#
#                                                    text  \
# 5550  russian river, sonoma county, california red u...
# 5551  russian river, sonoma county, california red u...
# 5552  oakville, napa valley, california red usa oakv...
# 5553  napa valley, california red usa span style col...
# 5554  sonoma county, california red usa nana fruity ...
# 5555  napa valley, california red usa close eyes sme...
#
#                                     description_clean_2  \
# 5550  [outstanding, showcase, appellation, sourced, ...
# 5551  [nanthe, lynmar, winery, russian, river, pinot...
# 5552  [oakville, winery, zinfandel, excellent, job, ...
# 5553  [span, style, color, rgb, fresh, herb, notes, ...
# 5554  [nana, fruity, leathery, nose, offers, glimpse...
# 5555  [close, eyes, smell, wine, might, think, moved...
#
#                                                  text_2
# 5550  [russian, river,, sonoma, county,, california,...
# 5551  [russian, river,, sonoma, county,, california,...
# 5552  [oakville,, napa, valley,, california, red, us...
# 5553  [napa, valley,, california, red, usa, span, st...
# 5554  [sonoma, county,, california, red, usa, nana, ...
# 5555  [napa, valley,, california, red, usa, close, e...

# %%
recommender_df['Gary Farrell Russian River Selection Pinot Noir'].sort_values()[1:11]
# Out:
# 5636    0.307555
# 5180    0.312158
# 5053    0.312741
# 4957    0.312777
# 5398    0.316472
# 8554    0.317532
# 4774    0.317773
# 5485    0.318231
# 4731    0.318879
# 4658    0.320760
# Name: Gary Farrell Russian River Selection Pinot Noir, dtype: float64

# %%
recommender_df2['Gary Farrell Russian River Selection Pinot Noir'].sort_values()[1:11]
# Out:
# 5082    0.209751
# 4658    0.213270
# 4859    0.216470
# 4735    0.217534
# 4774    0.227940
# 5863    0.231019
# 5361    0.232554
# 6317    0.232586
# 5422    0.234921
# 5672    0.235014
# Name: Gary Farrell Russian River Selection Pinot Noir, dtype: float64

# %%
df.loc[5636, 'name']
# Out:
# 'Joseph Phelps Freestone Vineyards Sonoma Coast Pinot Noir'

# %% [markdown]
# ## Need Pieces - Testing on breakin up by color

# %% [markdown]
# Initial stages of building a recommnders. Changed the index to index corresponding to wines. Need to get words to find most similar wine in df to recommend from here.

# %%
w2v_sg_white = Word2Vec(df_white['description_clean_2'],
                  min_count=1, 
                  sg=1, 
                  workers=3)

# %%
# recommender_df['Skin Contact Silvaner "Kleine Heimat," 2Naturkinder'].sort_values()[1:11]
recommender_df[df.loc[23]['name']].sort_values()[1:11]
# Out:
# 22       0.377764
# 21       0.377764
# 1916     0.559868
# 2480     0.592201
# 1942     0.599560
# 2084     0.601497
# 10144    0.607226
# 2597     0.613014
# 1787     0.613121
# 3077     0.619425
# Name: Agrapart "Crus 7" Blanc de Blancs Brut  NV, dtype: float64

# %%
df.loc[1916 , 'name']
# Out:
# 'Le Brun Servenay, Extra Brut Millésime, Vieilles Vignes, Grand Cru'

# %%
w2v_sg_white.wv.most_similar_cosmul(['bright', 'white', 'juicy'])
# Out:
# [('delightfully', 0.8403853178024292),
#  ('fragrant', 0.8399611115455627),
#  ('grassy', 0.8391693830490112),
#  ('appealing', 0.8361043334007263),
#  ('bursting', 0.8358244895935059),
#  ('delicate', 0.8328315615653992),
#  ('alluring', 0.8316115140914917),
#  ('burst', 0.8299099206924438),
#  ('citric', 0.8294507265090942),
#  ('exuberant', 0.8270400166511536)]

# %%
def search_docs(word, number_of_articles):
    new_vec = bigrams_model.infer_vector([word])
    tag_list = bigrams_model.docvecs.most_similar([new_vec])[0:number_of_articles]
    sims = []
    tags = []
    for num in tag_list:
        tags.append(num[0])
        sims.append(num[1])
    dfs = []
    for t in tags:
        dfs.append(df_white.iloc[t, :])
    new_df = pd.DataFrame(dfs)
    new_df['similarity_percentage'] = sims
    return new_df

# %%
df_white['description'] = [str(row).lstrip('nan') for row in df_white['description']]
# Out:
# /Users/jobethschroeter/opt/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
search_docs('acid', 6)
# Out:
#                                                     name producer vintage  \
# 12795  Gunderloch Nackenheimer Rothenberg Riesling Au...        0    2017
# 7357                                  Ca'Momi Chardonnay        0    2018
# 12720                     Von Winning Sauvignon Blanc II        0    2019
# 10679                         Maison Matisco Saint-Veran        0    2016
# 7389                        PlumpJack Reserve Chardonnay        0    2018
# 2156             Prosecco "Fedéra" Extra Dry, Miotto  NV   Miotto      NV
#
#       bottle_size  color  price  country  \
# 12795         750  white     65  germany
# 7357          750  white     20      usa
# 12720         750  white     24  germany
# 10679         750  white     23   france
# 7389          750  white     59      usa
# 2156          1.5  white     34    italy
#
#                                       region  \
# 12795                   rheinhessen, germany
# 7357                 napa valley, california
# 12720                         pfalz, germany
# 10679  st-veran, maconnais, burgundy, france
# 7389                 napa valley, california
# 2156                                  veneto
#
#                                                      url  \
# 12795  https://www.wine.com/product/gunderloch-nacken...
# 7357   https://www.wine.com/product/camomi-chardonnay...
# 12720  https://www.wine.com/product/von-winning-sauvi...
# 10679  https://www.wine.com/product/maison-matisco-sa...
# 7389   https://www.wine.com/product/plumpjack-reserve...
# 2156   https://www.astorwines.com/SearchResultsSingle...
#
#                                              description            grape  \
# 12795  [Super-ripe apricot character and a stunning i...         riesling
# 7357   [Buttery, with plush, creamy apple pastry and ...       chardonnay
# 12720  An unmistakeable aroma of juicy gooseberries, ...  sauvignon blanc
# 10679  This is Maison Matisco’s star wine, with a bea...       chardonnay
# 7389   The 2018 PlumpJack Chardonnay is packed with t...       chardonnay
# 2156   One of the greatest Prosecco wines to hit our ...            glera
#
#            subregion                                  description_clean  \
# 12795              0  super ripe apricot character stunning interpla...
# 7357               0  buttery plush creamy apple pastry dried mango ...
# 12720              0  nanan unmistakeable aroma juicy gooseberries l...
# 10679       burgundy  nanthis maison matisco star wine beautiful pal...
# 7389               0  nanthe plumpjack chardonnay packed fresh aroma...
# 2156   valdobbiadene  one greatest prosecco wines hit shelves quite ...
#
#                                                     text  \
# 12795  rheinhessen, germany white germany super ripe ...
# 7357   napa valley, california white usa buttery plus...
# 12720  pfalz, germany white germany nanan unmistakeab...
# 10679  st-veran, maconnais, burgundy, franceburgundy ...
# 7389   napa valley, california white usa nanthe plump...
# 2156   venetovaldobbiadene white italy one greatest p...
#
#                                      description_clean_2  \
# 12795  [super, ripe, apricot, character, stunning, in...
# 7357   [buttery, plush, creamy, apple, pastry, dried,...
# 12720  [nanan, unmistakeable, aroma, juicy, gooseberr...
# 10679  [nanthis, maison, matisco, star, wine, beautif...
# 7389   [nanthe, plumpjack, chardonnay, packed, fresh,...
# 2156   [one, greatest, prosecco, wines, hit, shelves,...
#
#                                                   text_2  \
# 12795  [rheinhessen,, germany, white, germany, super,...
# 7357   [napa, valley,, california, white, usa, butter...
# 12720  [pfalz,, germany, white, germany, nanan, unmis...
# 10679  [st-veran,, maconnais,, burgundy,, franceburgu...
# 7389   [napa, valley,, california, white, usa, nanthe...
# 2156   [venetovaldobbiadene, white, italy, one, great...
#
#        similarity_percentage
# 12795               0.995969
# 7357                0.995503
# 12720               0.995058
# 10679               0.994713
# 7389                0.993790
# 2156                0.993132

# %%
recommender_df2['EglyOuriet, Grand Cru Brut'].sort_values()[1:6]
# Out:
# 10776    0.343650
# 2724     0.355140
# 439      0.357030
# 7870     0.363189
# 2044     0.375894
# Name: EglyOuriet, Grand Cru Brut, dtype: float64

# %%
recommender_df2['Covenant "Lavan" Chardonnay, Kosher'].sort_values()[1:3]
# Out:
# 851    0.414492
# 174    0.422725
# Name: Covenant "Lavan" Chardonnay, Kosher, dtype: float64

# %%
print(df.loc[10776, 'name'])
print(df.loc[2724, 'name'])
print(df.loc[851, 'name'])
print(df.loc[174, 'name'])
# Out:
# Simonnet-Febvre Cremant de Bourgogne Brut
# Savart Premier Cru "Accomplie," Extra Brut                                                            NV
# Covenant, The Tribe Chardonnay
# Baron Herzog Chenin Blanc, Kosher
